# %%
from neo_api_client import NeoAPI
import pickle

# %%
client = NeoAPI(consumer_key="vn9tFTTl0ZECtoLHOrMOzuUoquUa",
                consumer_secret="o1PDGixHl41u_a2Q0NWOB3WSsf4a",
                environment='PROD')
                # on_message=on_message, on_error=on_error,
                # on_close=None, on_open=None)

# access_token = client.configuration.bearer_token
# Out:
# {"data": {"access_token": "eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..L_6PS6vpTyhy2x7FfXtW99AJwlmFDTxOG1oOmB8TF8eXLr_A614S50HWNVOeugC0Igy6_1gSOvEIyWbED-8P2mzAkzaZG2aqOTnRSdIlSsEZRLWKgdBM6E3EddIp2vLerD4y6PPzZe4OJm9Q8R7SnvC6pm0_amXx6QHEUdFroaQGawcnLRyGcKnoofnuhpX1-IDsK0TuuaywA5twSHd96ZbI6BLSv4QVFjs2mr6qYunyAImJz_v1kXwZcog3kk1Z9wJVNaIx3FvayXHSnb-wwji_ZggdRWT9njshNnLrZQYcDjSDEnQeFBVZQoebD8MuAxDuNPG1wTVxsZnsiyei_w
# ...

# %%
creds = { "akshay" : {"number":"7019073542","password":"Ak@96633"},
         "venkatesh" : {"number": "9591259933", "password": "Kannada1$"}}

# %%
try:
    # Login using password
    user = 'akshay'
    ret = client.login(mobilenumber=creds[user]["number"], password=creds[user]["password"])
    print(ret)
except Exception as e:
    print("Exception when calling SessionApi->login: %s\n" % e)
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..BYg1k0KiyPzc08wOSmmTyRPefRsf-xrj99l76_9vsuwICpRNwuW1mcoViMVUSQ1VuZ1XbX9sx8iXNFvVFPWYJKTDlJ66pNB9tv9zOTi5ZkDwSvhBOfuipE_lCcWeAehYNaw9yHTtkDLVJnbmKNVP4Pe7EgDGTmV9aKvougmQmjZG5_zi9z0zU2DWkMCpt0yNf3USO7VP4Op5ToInCp50VyQykAleyBqNu0zDr_8qhsvoCJX-bxLTGtXSiV1iXogs_WsvBKOdxekggYtgAsXAHnG16M-6aLeHmzCDhY290abia_h23zaIF7ln6yE3BeQG8kVShMe6_wzjBt1RFmyrlg', 'sid': '36c0be09-4384-401b-bcf7-5523ce16e8aa', 'rid': 'a4284ec0-4b11-488f-ba41-6757cb541830', 'hsServerId': '', 'isUserPwdExpired': False, 'caches': {'baskets': '1760430342', 'lastUpdatedTS': '1760430342', 'multiplewatchlists':
# ...

# %%
client.session_2fa(OTP=input())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 client.session_2fa(OTP=input())
#
# File ~/dev/AlgoTrading/.venv/lib/python3.11/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/dev/AlgoTrading/.venv/lib/python3.11/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# ...

# %%
with open("./client.pkl",'wb') as file:
    pickle.dump(client,file)

# %%
with open("./client.pkl",'rb') as file:
    client_2 = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 with open("./client.pkl",'rb') as file:
# ----> 2     client_2 = pickle.load(file)
#
# NameError: name 'pickle' is not defined

# %%
client.scrip_master()
# Out:
# {'filesPaths': ['https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-07-08/transformed/bse_cm.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-07-08/transformed/nse_cm.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-07-08/transformed/cde_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-07-08/transformed/mcx_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-07-08/transformed/nse_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-07-08/transformed/bse_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-07-08/transformed/nse_com.csv'],
#  'baseFolder': 'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod'}

# %%
# # client.place_order(exchange_segment='NFO', 
client_2.place_order(exchange_segment='BFO', 
                   product='NRML', 
                   price='0', 
                   order_type='MKT', 
                   quantity='75', 
                   validity='DAY', 
                   trading_symbol='SENSEX2570883400CE',
                   transaction_type='S', 
                   amo="NO", 
                #    disclosed_quantity="1", 
                   market_protection="0", 
                   pf="N",
                   trigger_price="0", 
                   tag=None)

# client.place_order(exchange_segment='NFO', 
# client_2.place_order(exchange_segment='NFO', 
#                    product='NRML', 
#                    price='0', 
#                    order_type='MKT', 
#                    quantity='1', 
#                    validity='DAY', 
#                    trading_symbol='NIFTY2570325500CE',
#                    transaction_type='B', 
#                    amo="NO", 
#                    disclosed_quantity="0", 
#                    market_protection="0", 
#                    pf="N",
#                    trigger_price="0", 
#                    tag=None)
# Out:
# {'stCode': 1009,
#  'errMsg': 'please provide valid lotwise quantity',
#  'stat': 'Not_Ok'}

# %%
# client.place_order(exchange_segment='NFO', 
client_2.place_order(exchange_segment='NFO', 
                   product='NRML', 
                   price='0', 
                   order_type='MKT', 
                   quantity='1', 
                   validity='DAY', 
                   trading_symbol='NIFTY2510924000CE',
                   transaction_type='S', 
                   amo="NO", 
                   disclosed_quantity="1", 
                   market_protection="0", 
                   pf="N",
                   trigger_price="0", 
                   tag=None)
# Out:
# {'stat': 'Not_Ok',
#  'stCode': 5202,
#  'errMsg': 'Error: Scrip Details Not Found',
#  'tid': 'server1_158707'}

# %%
positions = client_2.positions()
profits = []
for i in positions['data']:
    TotalBuyQty = (i["cfBuyQty"] + i["flBuyQty"])
    TotalSellqty = (i["cfSellQty"] + i["flSellQty"])
    TotalBuyAmt = i["buyAmt"]
    TotalSellAmt = ( i["sellAmt"])
    profits.append(float(TotalSellAmt)-float(TotalBuyAmt))
sum(profits)
# Out:
# 9630.0

# %%
t = 'NIFTY2511623300PE'

# %%
for i in positions['data']:
    if(i['trdSym'] == t):
        TotalBuyQty = (i["cfBuyQty"] + i["flBuyQty"])
        TotalSellqty = (i["cfSellQty"] + i["flSellQty"])
        TotalBuyAmt = i["buyAmt"]
        TotalSellAmt = ( i["sellAmt"])
        print(float(TotalSellAmt)-float(TotalBuyAmt))
# Out:
# 0.0
