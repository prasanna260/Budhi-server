# %%
from neo_api_client import NeoAPI
import pickle

# %%
client = NeoAPI(consumer_key="p_g3UNvXchg103gBueKsKrJTezsa",
                consumer_secret="cTeUXwCYPeFRwx9nvsv_qtrQsAYa",
                environment='PROD')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client = NeoAPI(consumer_key="p_g3UNvXchg103gBueKsKrJTezsa",
#       2                 consumer_secret="cTeUXwCYPeFRwx9nvsv_qtrQsAYa",
#       3                 environment='PROD')
#
# TypeError: NeoAPI.__init__() got an unexpected keyword argument 'consumer_secret'. Did you mean 'consumer_key'?

# %%
creds = { "akshay" : {"number":"7019073542","password":"Ak@70190"},
         "venkatesh" : {"number": "9591259933", "password": "Kannada1$"}}

# %%
try:
    # Login using password
    ret = client.login(mobilenumber=creds["akshay"]["number"], password=creds["akshay"]["password"])
    print(ret)
    res = client.session_2fa(OTP=input())
    print(res)
except Exception as e:
    print("Exception when calling SessionApi->login: %s\n" % e)
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..lvunorhUxZ7tYj8xzwJBZRJwelskTgvHaQA0v2TLzhOy6TMhCDKVkiCWYIqjv38aOXQr1v8TyoUZbfKRgpIOgr_3CVbssZ3SevHJqjcZPV_q0mTu3-kvcPFJ0CgUZ4Uq2dwc6qt9DgwZmVP3DRPosUiR9ndZCyCEpbsTLPWBr_0qLHya1HqvDkPAcEoUtcZoMFA_UDJY6GSyEyNirfjgeCJ0bxQCs6JvARxSwq6TUc21PjryWvjQSg-vbpELnYiJub2RiBzG5MPg65tk-Jdgyf--zNFqdRCFpSffmfnJeAUTQaqwunTYERsn-IPLJE6OjtQ3b_RC-EQNO6pji2_WmQ', 'sid': '38f1249c-57ea-47e7-b1fe-5fbeca38019f', 'rid': '2352fba2-c44f-4f88-9d8c-b606b54f1b2a', 'hsServerId': 'server2', 'isUserPwdExpired': False, 'caches': {'baskets': '1737085734', 'lastUpdatedTS': '1737085734', 'multiplewatch
# ...

# %%
with open("./client.pkl",'wb') as file:
    pickle.dump(client,file)

# %%
with open("./client.pkl",'rb') as file:
    client_2 = pickle.load(file)

# %%
client.scrip_master()
# Out:
# {'filesPaths': ['https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-01-20/transformed/bse_cm.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-01-20/transformed/cde_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-01-20/transformed/mcx_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-01-20/transformed/nse_cm.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-01-20/transformed/nse_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-01-20/transformed/bse_fo.csv'],
#  'baseFolder': 'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod'}

# %%
client_2.place_order(exchange_segment='NFO', 
                   product='NRML', 
                   price='0', 
                   order_type='MKT', 
                   quantity='1', 
                   validity='DAY', 
                   trading_symbol='NIFTY2511624000CE',
                   transaction_type='S', 
                   amo="NO", 
                   disclosed_quantity="1", 
                   market_protection="0", 
                   pf="N",
                   trigger_price="0", 
                   tag=None)
# Out:
# {'stat': 'Not_Ok',
#  'stCode': 5202,
#  'errMsg': 'Error: Scrip Details Not Found',
#  'tid': 'server2_1437'}

# %%
# Step 2: Validate with MPIN
resp2 = client.totp_validate(mpin="647800")  # Your 4-6 digit MPIN
print("Validate response:", resp2)

# After this, the client will have session tokens
print("Session token:", getattr(client, 'session_token', None))
# Out:
# Validate response: {'error': [{'code': 400, 'message': "Missing required field 'Auth'"}, {'code': 400, 'message': "Missing required field 'Sid'"}, {'code': 400, 'message': "Invalid field 'NeoFinKey'; must contain only alphabetical"}]}
# Session token: None

# %%
from neo_api_client import NeoAPI

# Create client (use 'prod' for live trading)
client = NeoAPI(consumer_key="p_g3UNvXchg103gBueKsKrJTezsa", consumer_secret="cTeUXwCYPeFRwx9nvsv_qtrQsAYa", environment='prod', access_token=None, neo_fin_key=None)
# Out:
# {"data": {"access_token": "eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..KG2xkZYLfwijYO35nTCWtOqvauAzB9FQpDlMs47KXo4qbpnjMxjuRPQJdSfF3m8_pIV4eBNtfAJBYuZT5T3uXnVUAyNGoYt6qSqTvdTbAqQgwsE37EizfOY2IOAuWjbz2CU9ZFYHshDJ_I4kFop-ljN8rVhFvQFaon4jJHyWXrBQSKichXXaTemI5haUmlDJKhZWUs7YvmB-Qn6IcCF0POgyBjiGehFRVeghV0P5dj7xZIGXqUCIS_Q6yxd2bFAcROOYEJ49L9QUX0c_k0ASjemXnaS1cQ9nAo2ZqekchOS0RAJaFZgDcIJs-UvGsYqIr9XEXDX_5g9p14gVRyy-Tw
# ...

# %%
# Step 1 — Login
client.login(mobilenumber="+919962891419", password="Sinaamika@25")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..IyGquTp77v4NGePmZQSgbZFVy-9biK_PJR-vFaq1_AxNY0ElTUTSnhdmeVTGZwZ3DFlkMygbkzlrcYcm-zQajXCidhYhuZOIgs5VERVmISbro69I4EBCr_8EPX8gPuY2cYDJ6AY0pgFk3ZDwAj80nsQN3tgfjOC82FDjAWxOY9YU0WcPzieznWYboLE1dY-tv4FuooKFX7yJrbGC3VvhhgaOQpsOCy8RsALUWvC4QTnpodrtOeL9Oo38pu3JUrOIVHM7X-K0cIir30NbYhGPZ5tgx8VYwRulsYfszihnuVSsPSE52LB1TvCIm08rJg4uA5HAGGDVaQgKwGRbYuYb2w',
#   'sid': '692339c5-37f5-4874-ab89-5d53f79520fd',
#   'rid': '771c7c59-9878-4563-805c-c2d4eeb86e52',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1762928910',
# ...

# %%
# Step 2 — Two-Factor Authentication (OTP)
# You will receive an OTP (SMS or TOTP if configured)
client.session_2fa(OTP="2521")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9._eFx1MDAwMFxiXHUwMDA2e1x1MDAwMFx1MDAxMGIiLCJmZXRjaGNhY2hpbmdydWxlIjowLCJjYXRlZ29yaXNhdGlvbiI6IiJ9.RlX0zGhAfvcWnGyttzD5CV6NbFbV6pzA0k3EqvSk_EV0yWPWcU-8_sQOewiFF2Z93JUTGCAUN9Zxm6l_HeeBiq8vbRyf9u0h6ryYTSm75XKgx3GoJB98KH36jihTlT9D3Ri57jkbuyMX5HwLCkRo4ZqJLiDD1J3LOFbCV802iw-RfzOCka6HD0fz_05f9qQ2U4GhGarAsftjg-Vl4-kwgzJ76WampD-d9LBKQjfNndzx-jzQClSl7sguUjDJ82AckzYYpVj_KpaBBYPJnJXbkuKl_F8dQxWOKOLpivYk-IqSDjcp1VkZyEDrHCVHIPJPR_AlZNFHcBcZcC1QRpMPEg',
#   'sid': '692339c5-37f5-4874-ab89-5d53f79520fd',
#   'rid': '771c7c59-9878-4563-805c-c2d4eeb86e52',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1762928910',
# ...

# %%
# Step 3: Retrieve portfolio info
holdings = client.holdings()
positions = client.positions()
limits = client.limits(segment="", exchange="", product="")

print("Holdings:", holdings)
print("Positions:", positions)
print("Limits:", limits)
# Out:
# Holdings: {'data': [{'averagePrice': 19.5657, 'quantity': 750, 'exchangeSegment': 'nse_fo', 'exchangeIdentifier': '119218', 'holdingCost': 14674.275, 'mktValue': 14925, 'scripId': 'a21f9261e4e59a6301b5034fc7b37479f22273a6', 'instrumentToken': 78385, 'instrumentType': 'Options', 'isAlternateScrip': True, 'closingPrice': 19.9, 'expiryDate': '25-NOV-2025', 'strikePrice': '3200.00', 'optType': 'CE', 'symbol': 'SIEMENS', 'instrumentStatus': 'ACTV', 'instrumentName': 'OPTSTKSIEMENS   25NOV2025CE   3200.00', 'sector': 'Others', 'sellableQuantity': 0, 'securityType': 'NSEDERV ', 'securitySubType': 'EQUITY OPTION'}]}
# ...
